# %%
import pandas as pd
import json
import numpy
import matplotlib.pyplot as plt
import seaborn

# %%
Min_Cal_Req = pd.read_table('/Users/emilyharris/Python Stuff/data/Minimum_cal_requirements.txt')
df2 = pd.DataFrame(Min_Cal_Req)
df2.pop("Code")
print(df2["DCS"].mean())
print(df2)
Ind_Water = pd.read_table('/Users/emilyharris/Python Stuff/data/Ind_Water.txt')
df3 = pd.DataFrame(Ind_Water)
df3.pop("Code")
#print(df["DCS"].mean())
print(df3)
ag_water = pd.read_table('/Users/emilyharris/Python Stuff/data/Ag_Water.txt')
df4 = pd.DataFrame(ag_water)
df4.pop("Code")
#print(df["DCS"].mean())
print(df4)
Glo_Fre_Water = pd.read_table('/Users/emilyharris/Python Stuff/data/Glo_Fre_Water.txt')
df5 = pd.DataFrame(Glo_Fre_Water)
df5.pop("Code")
#print(df["DCS"].mean())
print(df5)
Glo_En = pd.read_table('/Users/emilyharris/Python Stuff/data/Glo_energy.txt')
df6 = pd.DataFrame(Glo_En)
df6.pop("Code")
df["Calories"].fillna(130, inplace = True)
#print(df["DCS"].mean())
print(df6)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Python Stuff/.venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/Python Stuff/.venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Python Stuff/.venv/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DCS'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.plot(kind='scatter', x = 'Year', y = '')

plt.show()

# %%
df.corr()
# Out:
# /var/folders/dl/8mhf96xn06x14bhhdb_j2zsr0000gn/T/ipykernel_72550/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                            Year  Daily caloric supply
# Year                   1.000000               0.255023
# Daily caloric supply   0.255023               1.000000

# %%
#df.plot(kind='scatter', x = 'country', y = 'Daily caloric supply (OWID based on UN FAO & historical sources)')
