# %%
import pandas as pd
import json
import numpy
import matplotlib.pyplot as plt

# %%
df = pd.read_table('/Users/emilyharris/Python Stuff/data/Global_Data.txt')
print(df)
df['Year'].mean()
print(df)
# Out:
#               Entity      Code  Year  \
# 0           Abkhazia  OWID_ABK  2015
# 1        Afghanistan       AFG  2002
# 2        Afghanistan       AFG  2003
# 3        Afghanistan       AFG  2004
# 4        Afghanistan       AFG  2005
# ...              ...       ...   ...
# 57848       Zimbabwe       ZWE  1968
# 57849       Zimbabwe       ZWE  1969
# 57850       Zimbabwe       ZWE  1970
# 57851       Zimbabwe       ZWE  2021
# 57852  Åland Islands       ALA  2015
#
#        Energy use (kg of oil equivalent per capita)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 57848                                           NaN
# 57849                                           NaN
# ...
